# %% [markdown]
# ## Задание 1

# %% [markdown]
# Написать код, который вычисляет сумму всех чисел, удовлетворяющих следующие условия:

# %% [markdown]
# положительные целые числа от 1 до 1_000_000_002 (один миллиард два) включительно

# %% [markdown]
# которые нацело (без остатка) делятся на 3 (пример: 3, 6, 9, ...)

# %% [markdown]
# и которые не заканчиваются на 4 и 7 (пример заканчивающихся на 4 и 7: 24, 27, 54, 57 ...)

# %%
import numpy as np

# %% [markdown]
# Мое решение 1 задачи

# %%
# %%time

n = 1000000003
answer = 0

for i in range(n):
    if i % 3 == 0 and \
    i % 10 != 7 and \
    i % 10 != 4:
        answer += i
# Out:
# Wall time: 2min 48s

# %%
print(answer)

# %% [markdown]
# Предлагаемое решение в лоб

# %%
# %%time

n = 1000000003
result_sum = 0

for i in range(3,1000000003, 3 ):
    if i % 10 not in [4, 7]: 
        result_sum += i
# Out:
# Wall time: 1min 2s

# %% [markdown]
# Хитрое решение

# %%
# %%time

print(sum(range(3, 1000000003, 3)) - sum(range(24, 1000000003, 30)) - sum(range(27, 1000000003, 30)))
# Out:
# 133333334466666672
# Wall time: 18.9 s

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Нужно подготовить текстовый файл из 1 строки.
#
# После последнего числа запятая не ставится.

# %% [markdown]
# Строка содержит набор из 3-х тысяч чисел, разделенных запятой. После последнего числа запятая не ставится.

# %% [markdown]
# каждое число - результат операции:
#
#     "результирующее целое число" = "целое число #1" применить "арифметическая операция" "целое число #2"

# %%
import string 
from numpy import array_split
import os

# %%
def convers_text(line):
    split_line = line.split(maxsplit = 3)
    s = '{0[1]} {0[0]} {0[2]}'.format(split_line)
    s = str(eval(s))
    #return s

# %%
def convers_text(line):
    split_line = line.split(maxsplit = 3)
    result = '{0[1]} {0[0]} {0[2]}'.format(split_line)
    result = str(eval(result))
    return result

list_of_results = list()

with open('input_file.txt','r') as text_input:
    for line in text_input: 
        split_line = line.split(maxsplit = 3)
        result = '{0[1]} {0[0]} {0[2]}'.format(split_line)
        result = str(eval(result))
        list_of_results.append(result)
        
list_of_results = ','.join(list_of_results)
        
with open('output_file.txt', 'w') as text_output:
        text_output.write(list_of_results)

# %% [markdown]
# Предлагаемое решение не выставляю, так мне кажется, что мое лучше

# %% [markdown]
# # Задача 3

# %% [markdown]
# На вход поступает два текстовый файл из 3-х тысяч строк каждый.

# %% [markdown]
# Первый файл содержит строки текста.

# %% [markdown]
# Второй файл содержит строки из двух целых неотрицательных чисел.

# %% [markdown]
# Первое число в строке всегда меньше или равно второму.

# %% [markdown]
# Числа всегда меньше длины соответствующей строки первого файла.
# Соответствующей - это значит 1-ая строка из 1-го файла соответствует 1-ой строке из 2-го файла, а 123-я строка из 1-го файла соответствует 123-ей строке из 2-го файла.

# %% [markdown]
# Подготовить выходной файл, который состоит из подстрок 1-го входного файла.

# %% [markdown]
# Подстроки разделены пробелами.
# Какие брать подстроки - написано во втором файле.
# В конце файла пробела нет.

# %%
def separator(text_line, number_line):
    splitted_text_line = list(text_line)
    number_split_line = number_line.split(maxsplit = 2)
    i = int(number_split_line[0])
    j = int(number_split_line[1]) 
    output_text = splitted_text_line[i:j+1]
    output_text = ''.join(output_text)
    
    return output_text

# %%
def separator(text_line, number_line):
    splitted_text_line = list(text_line)
    number_split_line = number_line.split(maxsplit = 2)
    i = int(number_split_line[0])
    j = int(number_split_line[1]) 
    output_text = splitted_text_line[i:j+1]
    output_text = ''.join(output_text)
    
    return output_text

list_of_results = []

with open('test_input_text.txt', 'r') as input_text, open('test_input_numbers.txt', 'r') as input_numbers:
    for text_line, number_line in zip(input_text, input_numbers):
        output_text = separator(text_line, number_line)
        list_of_results.append(output_text)
        
list_of_results = ' '.join(list_of_results)     
                        
with open('task_3_output_file.txt', 'w') as text_output:
        text_output.write(list_of_results)

# %% [markdown]
# # Задача 4

# %% [markdown]
# На вход поступает строка.
# В ней хранится набор химических символов (He, O, H, Mg, Fe, ...). Без пробелов.

# %% [markdown]
# Нужно расшифровать химические символы в название химических элементов.

# %%
import re
import json

text_output = []

periodic_table = json.load(open('periodic_table.json', 'rb')) 
with open('task_4_import_file.txt', 'r') as input_file:
    for line in input_file:
        splitted_text =  re.findall('[A-Z][^A-Z]*', line)
        for element in splitted_text:
            text_output.append(periodic_table[element])
text_output = ''.join(text_output)
print(text_output)
# Out:
# ХромКобальтРадийЛитийБорийМарганецМенделевийСамарийНихонийСвинецКальцийУранУранМолибденИридийПолонийЕвропийУглеродПрометийПолонийРубидийПлутонийОсмийЛоуренсийАргонКюрийПалладийЦерийАзотБерклийБарийЛантанМедьМышьякКалифорнийПразеодимКадмийБарийНеодимАлюминийАлюминийРутенийБарийТаллийФлеровийУнуненнийТеннессинРадонЦерийХромГафнийПрометийЛантанСвинецМенделевийКалифорнийБромБерклийПразеодимГадолинийЭйнштейнийУранКалифорнийНеонМагнийСамарийЛантанБорийЛютецийДармштадтийМолибденСамарийАлюминийКислородСвинецДубнийМедьЦерийЭйнштейнийЭйнштейнийКсенонКальцийМенделевийГелийСурьмаЛиверморийТорийАстатФторРутенийНиобийПразеодимЛитийМедьЛантанНикельИттербийМенделевийХлорАргонПрометийАктинийТулийГадолинийАстатЛиверморийСтронцийНеодимСкандийТулийФторМагнийУнуненнийТеннессинПалладийБромСамарийРутенийКислородТеллурАктинийЛютецийХассийТулийУнуненнийИттербийМарганецУглеродГафнийДиспрозийСвинецРадийСеленПрометийГафнийАлюминийКалийАзотИттрийРтутьПразеодимКсенонВольфрамВодородТеннессинАстатХассийГерманийМышь
# ...

# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
text = 'AzDEad'
splitted_text =  re.findall('[A-Z][^A-Z]*', text)
print(splitted_text)
# Out:
# ['Az', 'D', 'Ead']

# %%
import json


DataDict = []

with open('periodic_table.json', 'rb') as json_file:
    periodic_table = json.load(json_file)
    periodic_table.update(DataDict)
    print(periodic_table)
# Out:
# {'Ac': 'Актиний', 'Ag': 'Серебро', 'Al': 'Алюминий', 'Am': 'Америций', 'Ar': 'Аргон', 'As': 'Мышьяк', 'At': 'Астат', 'Au': 'Золото', 'B': 'Бор', 'Ba': 'Барий', 'Be': 'Бериллий', 'Bh': 'Борий', 'Bi': 'Висмут', 'Bk': 'Берклий', 'Br': 'Бром', 'C': 'Углерод', 'Ca': 'Кальций', 'Cd': 'Кадмий', 'Ce': 'Церий', 'Cf': 'Калифорний', 'Cl': 'Хлор', 'Cm': 'Кюрий', 'Cn': 'Коперниций', 'Co': 'Кобальт', 'Cr': 'Хром', 'Cs': 'Цезий', 'Cu': 'Медь', 'Db': 'Дубний', 'Ds': 'Дармштадтий', 'Dy': 'Диспрозий', 'Er': 'Эрбий', 'Es': 'Эйнштейний', 'Eu': 'Европий', 'F': 'Фтор', 'Fe': 'Железо', 'Fl': 'Флеровий', 'Fm': 'Фермий', 'Fr': 'Франций', 'Ga': 'Галий', 'Gd': 'Гадолиний', 'Ge': 'Германий', 'H': 'Водород', 'He': 'Гелий', 'Hf': 'Гафний', 'Hg': 'Ртуть', 'Ho': 'Гольмий', 'Hs': 'Хассий', 'I': 'Йод', 'In': 'Индий', 'Ir': 'Иридий', 'K': 'Калий', 'Kr': 'Криптон', 'La': 'Лантан', 'Li': 'Литий', 'Lr': 'Лоуренсий', 'Lu': 'Лютеций', 'Lv': 'Ливерморий', 'Mc': 'Московий', 'Md': 'Менделевий', 'Mg': 'Магний', 'Mn': 'Марганец
# ...

# %%
import re
import json

periodic_table = json.load(open('periodic_table.json', 'rb'))
print(periodic_table)
# Out:
# {'Ac': 'Актиний', 'Ag': 'Серебро', 'Al': 'Алюминий', 'Am': 'Америций', 'Ar': 'Аргон', 'As': 'Мышьяк', 'At': 'Астат', 'Au': 'Золото', 'B': 'Бор', 'Ba': 'Барий', 'Be': 'Бериллий', 'Bh': 'Борий', 'Bi': 'Висмут', 'Bk': 'Берклий', 'Br': 'Бром', 'C': 'Углерод', 'Ca': 'Кальций', 'Cd': 'Кадмий', 'Ce': 'Церий', 'Cf': 'Калифорний', 'Cl': 'Хлор', 'Cm': 'Кюрий', 'Cn': 'Коперниций', 'Co': 'Кобальт', 'Cr': 'Хром', 'Cs': 'Цезий', 'Cu': 'Медь', 'Db': 'Дубний', 'Ds': 'Дармштадтий', 'Dy': 'Диспрозий', 'Er': 'Эрбий', 'Es': 'Эйнштейний', 'Eu': 'Европий', 'F': 'Фтор', 'Fe': 'Железо', 'Fl': 'Флеровий', 'Fm': 'Фермий', 'Fr': 'Франций', 'Ga': 'Галий', 'Gd': 'Гадолиний', 'Ge': 'Германий', 'H': 'Водород', 'He': 'Гелий', 'Hf': 'Гафний', 'Hg': 'Ртуть', 'Ho': 'Гольмий', 'Hs': 'Хассий', 'I': 'Йод', 'In': 'Индий', 'Ir': 'Иридий', 'K': 'Калий', 'Kr': 'Криптон', 'La': 'Лантан', 'Li': 'Литий', 'Lr': 'Лоуренсий', 'Lu': 'Лютеций', 'Lv': 'Ливерморий', 'Mc': 'Московий', 'Md': 'Менделевий', 'Mg': 'Магний', 'Mn': 'Марганец
# ...
